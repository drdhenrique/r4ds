# %% [markdown]
# <a href="https://colab.research.google.com/github/drdhenrique/r4ds/blob/main/r4ds_cap1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.2     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
dados <- mpg

dados$new_col <- mpg$displ^2

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy))
# Out:
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy, color = class))
# Out:
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy, size = class))
# Out:
# Warning message:
# “Using size for a discrete variable is not advised.”
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy, alpha = class))
# Out:
# Warning message:
# “Using alpha for a discrete variable is not advised.”
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy, shape = class))
# Out:
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 7. Consider
# specifying shapes manually if you must have them.”
# Warning message:
# “Removed 62 rows containing missing values (`geom_point()`).”
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy), color = 'blue')
# Out:
# plot without title

# %%
# O que acontece se roda o código abaixo?

ggplot(data = mpg)

# Gráfico vazio!
# Out:
# plot without title

# %%
# Quantas linhas e colunas tem no dataset mpg?

dim(mpg)

# Logo 234 linhas e 11 colunas. Outra forma é só chamar o conjunto

mpg
# Out:
# [1] 234  11
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro         1.8   1999 4   manual(m5) 4   18  26  p
# 9   audi         a4 quattro         1.8   1999 4   auto(l5)   4   16  25  p
# 10  audi         a4 quattro         2.0   2008 4   manual(m6) 4   20  28  p
# 11  audi         a4 quattro         2.0   2008 4   auto(s6)   4   19  27  p
# ...

# %%
# O que drv descreve?

?mpg

# drv the type of drive train, where f = front-wheel drive, r = rear wheel drive, 4 = 4wd

# %%
ggplot(data = dados) +
  geom_point(mapping = aes(x = hwy, y = cyl))
# Out:
# plot without title

# %%
ggplot(data = dados) +
  geom_point(mapping = aes(x = class, y = drv))

# Esse tipo de gráfico não é útil pois ele só fala que tipos de tração cada tipo de carro tem
# Out:
# plot without title
